# %%
import matplotlib.pyplot as plt
import random
import numpy as np
from sklearn.cluster import KMeans
from sklearn import decomposition
from sklearn import preprocessing
from pathlib import Path
import scipy.io
import py_pcha
import os
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
from sklearn.cluster import MiniBatchKMeans, KMeans
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import decomposition
from sklearn import preprocessing
from pathlib import Path
import scipy.io
import py_pcha

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
# load labels
labels=pd.read_csv('labels.csv',names=['age','gender','race']) # gender 0 male, 1 female (Races from 0 to 4)
labels.head()
# Out:
#    age  gender  race
# 0  100       0     0
# 1  100       0     0
# 2  100       1     0
# 3  100       1     0
# 4  100       1     0

# %%
data_paths = os.listdir('Faces')
n=len(data_paths)
p=200*200 # we add the label as the first element
X=np.zeros([n,p])
race=np.zeros(n)
gender=np.zeros(n)
age=np.zeros(n)
print(f'number of observations: {n}, number of features: {p}')
# load images
for idx,el in enumerate(data_paths):
    img=plt.imread('Faces/'+el)
    img_gray=rgb2gray(img)
    img_gray_norm=img_gray/255.0
    flatten=img_gray_norm.flatten()
    # get the label
    race[idx]=labels.iloc[int(el[:-4]),2]
    gender[idx]=labels.iloc[int(el[:-4]),1]
    age[idx]=labels.iloc[int(el[:-4]),0]
    # hstack label (as the first element) and pixels
    # features=np.hstack((race,flatten))
    X[idx]=flatten
# Out:
# number of observations: 23705, number of features: 40000

# %%
X.shape
# Out:
# (23705, 40000)

# %%
mean_img=np.mean(X,axis=0)

# %%
mean_img.shape
# Out:
# (40000,)

# %%
plt.imshow(mean_img.reshape(200,200),cmap='gray');plt.show()

# %%
X[1]-mean_img
# Out:
# array([ 0.27544425,  0.23908982,  0.15201193, ..., -0.19937395,
#        -0.21138591, -0.21957808])

# %% [markdown]
# ### Substract mean to perform PCA

# %%
X_non_mean=np.array([img-mean_img for img in X])
X_non_mean.shape
# Out:
# (23705, 40000)

# %%
plt.imshow(X_non_mean[0].reshape(200,200),cmap='gray');plt.show()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=100)
pca_scores=pca.fit_transform(X_non_mean[0:5000])
pca_scores.shape
# Out:
# (5000, 100)

# %%
Scores=pd.DataFrame(pca_scores)
Scores
# Out:
#              0          1          2          3          4         5   \
# 0    -20.994214 -18.314425   0.394824   8.069245   0.649835  5.155803
# 1     12.490785 -13.546862 -29.489503   3.075354   1.082621 -7.204906
# 2      7.462736  16.740052  -2.051953 -14.007741  -5.031466 -3.231994
# 3    -22.977421  -6.792701  -5.045476   0.778719 -19.398034  6.858391
# 4     22.796505 -33.935489   4.727148   1.590009  -1.717993 -9.056004
# ...         ...        ...        ...        ...        ...       ...
# 4995  46.962134   8.329299  -3.608747  -5.194207  -4.947729  2.746483
# 4996  29.505465  13.592485  27.046616  15.494613   8.285250  0.013065
# 4997  29.864373   7.197429  -8.494559   2.577796  -2.565818  5.668067
# 4998 -37.743563   4.371358   7.479625  -7.825150   4.293965 -2.634453
# 4999  -9.019669 -17.170225  22.677126   3.327300  -3.713895 -0.932677
#
#             6         7         8         9   ...        90        91  \
# 0    -5.688263  8.890270 -1.574895 -2.106948  ... -0.563208  1.558205
# 1    -5.465632  3.706318 -1.539326  2.176659  ... -0.079338 -0.782884
# 2     9.176907  8.000114  6.358063  1.812449  ... -0.134203 -0.811581
# 3    -0.668161  5.521757 -1.162393 -8.430886  ... -0.208960  1.879486
# 4    -3.750171  8.978570 -4.156174 -3.671654  ...  0.197700  0.563561
# ...        ...       ...       ...       ...  ...       ...       ...
# 4995 -0.004511 -2.372579 -4.499177 -5.577369  ...  0.624247 -0.511707
# 4996  0.426216 -3.814190 -2.897761  2.887656  ... -1.061899 -0.523496
# 4997  1.034596 -2.771988  3.685613 -8.972231  ...  0.481584  1.665403
# 4998 -2.219023 -2.299673  5.431140  0.221444  ... -0.917470  0.027287
# 4999 -1.450379 -1.734808 -2.118590  2.047322  ...  1.346658  0.275078
#
#             92        93        94        95        96        97        98  \
# 0    -1.089507 -1.418835 -0.995937  0.024281  0.661112 -0.270977  0.496393
# 1    -0.013899  0.604265 -0.040774  1.230398 -0.256342  1.039649  1.057669
# 2    -0.592998  0.652991 -0.028064 -0.725688  0.394670  0.107430 -0.550594
# 3    -0.734381  3.277892  1.600687  0.633769  0.696083 -0.977512 -1.068426
# 4     1.036431  0.564478 -0.210513  0.507515 -0.900948 -0.282848 -0.510945
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995 -0.840209 -1.449229 -0.569586  0.417295  0.409496 -0.831780 -1.137295
# 4996  0.211204  0.484895  0.782370  0.310602 -0.476173 -0.483607 -0.687143
# 4997 -1.374670  1.832099  1.083936  0.514084 -0.908406  1.537677  0.173635
# 4998  1.105002  1.007634 -0.450303  1.005145 -0.192456  0.668318 -0.861442
# 4999 -0.659158  0.437126  0.711694 -0.595322  0.234672  0.204804  0.683851
#
#             99
# 0    -1.301842
# 1    -0.617451
# 2     1.109522
# 3     1.579420
# 4    -0.957419
# ...        ...
# 4995  0.947982
# 4996 -0.098546
# 4997  1.067806
# 4998 -0.174117
# 4999 -0.165284
#
# [5000 rows x 100 columns]

# %%
Scores['race']=race[0:5000].astype('uint8')

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
sns.scatterplot(Scores[0],Scores[1],hue=Scores.race,palette="deep")
plt.show()

# %%
for i in range(0,5):
    [x,y]=[np.mean(Scores[Scores.race==i][0]),np.mean(Scores[Scores.race==i][1])]
    plt.scatter(x,y,label=i)
plt.legend();plt.show()

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.9238930363037989

# %%
for idx in range(0,5):
    print(len(labels[0:5000][labels[0:5000].race==idx]))
# Out:
# 1854
# 671
# 1031
# 848
# 596

# %% [markdown]
# ## Apply unsupervised learning

# %%
from sklearn.cluster import KMeans

# %%
# Declaring Model
model = KMeans(n_clusters=5)

# Fitting Model
model.fit(pca_scores)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Prediction on the entire data
all_predictions = model.predict(pca_scores)
print(all_predictions)
# Out:
# [4 1 0 ... 2 3 4]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(Scores[0],Scores[1],hue=all_predictions,palette="deep");plt.show()

# %% [markdown]
# ### TSNE clustering

# %%
from sklearn.manifold import TSNE

# Defining Model
model = TSNE(learning_rate=100)

# Fitting Model
transformed = model.fit_transform(pca_scores)

# Plotting 2d t-Sne
x_axis = transformed[:, 0]
y_axis = transformed[:, 1]

plt.figure(figsize=(10,6))
sns.scatterplot(x_axis,y_axis,hue=all_predictions,palette="deep");plt.show()

# %% [markdown]
# ### DBSCAN

# %%
dbscan.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
from sklearn.cluster import DBSCAN

# Declaring Model
dbscan = DBSCAN()

# Fitting
dbscan.fit(X_non_mean[0:5000])

# Transoring Using PCA
pca = PCA(n_components=2).fit(X_non_mean[0:5000])
pca_2d = pca.transform(X_non_mean[0:5000])

# Plot based on Class
for i in range(0, pca_2d.shape[0]):
    if dbscan.labels_[i] == 0:
        c1 = plt.scatter(pca_2d[i, 0], pca_2d[i, 1], c='r', marker='+')
    elif dbscan.labels_[i] == 1:
        c2 = plt.scatter(pca_2d[i, 0], pca_2d[i, 1], c='g', marker='o')
    elif dbscan.labels_[i] == -1:
        c3 = plt.scatter(pca_2d[i, 0], pca_2d[i, 1], c='b', marker='*')

plt.legend([c1, c2, c3], ['Cluster 1', 'Cluster 2', 'Noise'])
plt.title('DBSCAN finds 2 clusters and Noise')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sl/1xwn2w1j4x7c2rxkc6cdlnrh0000gn/T/ipykernel_87952/3270231456.py in <module>
#      20         c3 = plt.scatter(pca_2d[i, 0], pca_2d[i, 1], c='b', marker='*')
#      21
# ---> 22 plt.legend([c1, c2, c3], ['Cluster 1', 'Cluster 2', 'Noise'])
#      23 plt.title('DBSCAN finds 2 clusters and Noise')
#      24 plt.show()
#
# NameError: name 'c1' is not defined
